# %% [markdown]
# # Predicting ship collisions in the arctic sea

# %%
#Import Libraries
#Using: file:///C:/Users/shayl/Downloads/2018_Marine%20transportation%20risk%20assessment%20using%20Bayesian%20Network%20(1).pdf
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.lib.image as gumimage
import itertools

# %% [markdown]
# **Regarding the function below**<br>
# The getIterations function takes in an array of items that would be the inputs to the "or" gate in the Fault Tree, The variable that would be the output to the fault tree and then the decision network itself

# %%
#Helper methods
def count(items):
    num = 0
    for i in items:
        if i == 1:
            num = num+1
    if num<len(items)/2: #Check if should be < or <=
        return True
    else:
        return False

def getIterations(vars, mainVariable, dn):
    lst = list(itertools.product([0, 1], repeat=len(vars)))
    items = {}
    for i in lst:
        for j in range(len(vars)):
            items[vars[j]] = i[j]
        #print("Method insert for", mainVariable, "dictionary is", items, "with probabilities", "[1-0.00004396, 0.00004396]")
        dn.cpt(mainVariable)[items] = [1-0.00004396, 0.00004396]
        #print(items)
        #if count(i):
            #print("Method insert for", mainVariable, "dictionary is", items, "with probabilities 0.42")
            #dn.cpt(mainVariable)[items] = [1-0.00004396, 0.00004396]
        #else:
            #print("Method insert for",mainVariable, "dictionary is", items, "with probabilities 0.42")
            #dn.cpt(mainVariable)[items] = [1-0.00004396, 0.00004396]

# %% [markdown]
# # Construction

# %% [markdown]
# ## Define Nodes

# %%
#Define Nodes
dn = gum.InfluenceDiagram()
#Regular Nodes
var_names = ["Waves", "HighWind", "Fog", "PackIce", "RidgeIceAndIceberg", "Collision", "Environment", "HighSpeed", "EquipmentError", "RadarFailure", "HumanError", "ShipFault", "Navigation"]
waves, highwind, fog, packice, ridgeiceandiceberg, collision, environment, highspeed, equipmenterror, radarfailure, humanerror, shipfault, navigation = [dn.add(gum.LabelizedVariable(name, name, 2)) for name in var_names]
#The above are binary variables, region isn't so do that manually:
region = dn.add(gum.LabelizedVariable("Region", "Region", ["region1", "region2", "region3", "region4", "region5"]))
#Decision Node
changecourse = dn.addDecisionNode(gum.LabelizedVariable("ChangeCourse", "ChangeCourse", 2))
#Utility Node
u = dn.addUtilityNode(gum.LabelizedVariable("U", "U", 1))
gnb.showBN(dn,size="15")

# %% [markdown]
# ## Arcs

# %% [markdown]
# Add in Arcs

# %%
dn.addArc(region, waves)
dn.addArc(region, highwind)
dn.addArc(region, fog)
dn.addArc(region, packice)
dn.addArc(region, ridgeiceandiceberg)

dn.addArc(environment, waves)
dn.addArc(environment, highwind)
dn.addArc(environment, fog)
dn.addArc(environment, packice)
dn.addArc(environment, ridgeiceandiceberg)

dn.addArc(shipfault, navigation)
dn.addArc(shipfault, radarfailure)
dn.addArc(humanerror, navigation)
dn.addArc(equipmenterror, navigation)
dn.addArc(highspeed, navigation)
dn.addArc(environment, collision)
dn.addArc(shipfault, collision)

dn.addArc(navigation, collision)

dn.addArc(collision, u)
dn.addArc(changecourse, u)
gnb.showBN(dn,size="15")

# %% [markdown]
# # CPTs

# %% [markdown]
# ## CPT Region

# %% [markdown]
# For "Navigation" Effect I used the idea from this paper (https://reader.elsevier.com/reader/sd/pii/S0951832000000776?token=26EF05B58BEE12E1BFA7AF8C03ADFFF4715762438DDD0922D73E499AD84F80A194F925EA79A8B74025BECAE7F242470D&originRegion=eu-west-1&originCreation=20230504070556) as all gates represent causal relationships - therefore either true or false

# %%
#For Region
dn.cpt("Region").fillWith([1/5, 1/5, 1/5, 1/5, 1/5])
dn.cpt("Region")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F480)
#   Region                                         |
# region1  |region2  |region3  |region4  |region5  |
# ---------|---------|---------|---------|---------|
#  0.2000  | 0.2000  | 0.2000  | 0.2000  | 0.2000  |

# %% [markdown]
# ## CPTs for oberserved nodes

# %% [markdown]
# PackIce

# %%
dn.cpt("PackIce")[{"Region":"region1", "Environment":0}] = [1-0.0053, 0.0053]
dn.cpt("PackIce")[{"Region":"region2", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("PackIce")[{"Region":"region3", "Environment":0}] = [1-0.0037, 0.0037]
dn.cpt("PackIce")[{"Region":"region4", "Environment":0}] = [1-0.001, 0.001]
dn.cpt("PackIce")[{"Region":"region5", "Environment":0}] = [1-0.0001, 0.0001]
dn.cpt("PackIce")[{"Region":"region1", "Environment":1}] = [1-0.0053, 0.0053]
dn.cpt("PackIce")[{"Region":"region2", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("PackIce")[{"Region":"region3", "Environment":1}] = [1-0.0037, 0.0037]
dn.cpt("PackIce")[{"Region":"region4", "Environment":1}] = [1-0.001, 0.001]
dn.cpt("PackIce")[{"Region":"region5", "Environment":1}] = [1-0.0001, 0.0001]
dn.cpt("PackIce")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36E720)
#              ||  PackIce          |
# Region|Enviro||0        |1        |
# ------|------||---------|---------|
# region|0     || 0.9947  | 0.0053  |
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9963  | 0.0037  |
# region|0     || 0.9990  | 0.0010  |
# region|0     || 0.9999  | 0.0001  |
# region|1     || 0.9947  | 0.0053  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9963  | 0.0037  |
# region|1     || 0.9990  | 0.0010  |
# region|1     || 0.9999  | 0.0001  |

# %% [markdown]
# Fog (X7)

# %%
dn.cpt("Fog")[{"Region":"region1", "Environment":0}] = [1-0.05, 0.05]
dn.cpt("Fog")[{"Region":"region2", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("Fog")[{"Region":"region3", "Environment":0}] = [1-0.05, 0.05]
dn.cpt("Fog")[{"Region":"region4", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("Fog")[{"Region":"region5", "Environment":0}] = [1-0.0005, 0.0005]
dn.cpt("Fog")[{"Region":"region1", "Environment":1}] = [1-0.05, 0.05]
dn.cpt("Fog")[{"Region":"region2", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("Fog")[{"Region":"region3", "Environment":1}] = [1-0.05, 0.05]
dn.cpt("Fog")[{"Region":"region4", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("Fog")[{"Region":"region5", "Environment":1}] = [1-0.0005, 0.0005]
dn.cpt("Fog")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36EB40)
#              ||  Fog              |
# Region|Enviro||0        |1        |
# ------|------||---------|---------|
# region|0     || 0.9500  | 0.0500  |
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9500  | 0.0500  |
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9995  | 0.0005  |
# region|1     || 0.9500  | 0.0500  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9500  | 0.0500  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9995  | 0.0005  |

# %% [markdown]
# RidgeIceAndIceberg (X14)

# %%
dn.cpt("RidgeIceAndIceberg")[{"Region":"region1", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region2", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region3", "Environment":0}] = [1-0.05, 0.05]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region4", "Environment":0}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region5", "Environment":0}] = [1-0.005, 0.005]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region1", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region2", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region3", "Environment":1}] = [1-0.05, 0.05]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region4", "Environment":1}] = [1-0.01, 0.01]
dn.cpt("RidgeIceAndIceberg")[{"Region":"region5", "Environment":1}] = [1-0.005, 0.005]
dn.cpt("RidgeIceAndIceberg")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F2C0)
#              ||  RidgeIceAndIceber|
# Region|Enviro||0        |1        |
# ------|------||---------|---------|
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9500  | 0.0500  |
# region|0     || 0.9900  | 0.0100  |
# region|0     || 0.9950  | 0.0050  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9500  | 0.0500  |
# region|1     || 0.9900  | 0.0100  |
# region|1     || 0.9950  | 0.0050  |

# %% [markdown]
# Waves (X9)

# %%
dn.cpt("Waves")[{"Region":"region1", "Environment":0}] = [1-0.0023, 0.0023]
dn.cpt("Waves")[{"Region":"region2", "Environment":0}] = [1-0.0053, 0.0053]
dn.cpt("Waves")[{"Region":"region3", "Environment":0}] = [1-0.001, 0.001]
dn.cpt("Waves")[{"Region":"region4", "Environment":0}] = [1-0.00083, 0.00083]
dn.cpt("Waves")[{"Region":"region5", "Environment":0}] = [1-0.0001, 0.0001]
dn.cpt("Waves")[{"Region":"region1", "Environment":1}] = [1-0.0023, 0.0023]
dn.cpt("Waves")[{"Region":"region2", "Environment":1}] = [1-0.0053, 0.0053]
dn.cpt("Waves")[{"Region":"region3", "Environment":1}] = [1-0.001, 0.001]
dn.cpt("Waves")[{"Region":"region4", "Environment":1}] = [1-0.00083, 0.00083]
dn.cpt("Waves")[{"Region":"region5", "Environment":1}] = [1-0.0001, 0.0001]
dn.cpt("Waves")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36E680)
#              ||  Waves            |
# Region|Enviro||0        |1        |
# ------|------||---------|---------|
# region|0     || 0.9977  | 0.0023  |
# region|0     || 0.9947  | 0.0053  |
# region|0     || 0.9990  | 0.0010  |
# region|0     || 0.9992  | 0.0008  |
# region|0     || 0.9999  | 0.0001  |
# region|1     || 0.9977  | 0.0023  |
# region|1     || 0.9947  | 0.0053  |
# region|1     || 0.9990  | 0.0010  |
# region|1     || 0.9992  | 0.0008  |
# region|1     || 0.9999  | 0.0001  |

# %% [markdown]
# HighWind (X8)

# %%
dn.cpt("HighWind")[{"Region":"region1", "Environment":0}] = [1-0.0017, 0.0017]
dn.cpt("HighWind")[{"Region":"region2", "Environment":0}] = [1-0.0053, 0.0053]
dn.cpt("HighWind")[{"Region":"region3", "Environment":0}] = [1-0.0017, 0.0017]
dn.cpt("HighWind")[{"Region":"region4", "Environment":0}] = [1-0.0005, 0.0005]
dn.cpt("HighWind")[{"Region":"region5", "Environment":0}] = [1-0.0001, 0.0001]
dn.cpt("HighWind")[{"Region":"region1", "Environment":1}] = [1-0.0017, 0.0017]
dn.cpt("HighWind")[{"Region":"region2", "Environment":1}] = [1-0.0053, 0.0053]
dn.cpt("HighWind")[{"Region":"region3", "Environment":1}] = [1-0.0017, 0.0017]
dn.cpt("HighWind")[{"Region":"region4", "Environment":1}] = [1-0.0005, 0.0005]
dn.cpt("HighWind")[{"Region":"region5", "Environment":1}] = [1-0.0001, 0.0001]
dn.cpt("HighWind")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36EAC0)
#              ||  HighWind         |
# Region|Enviro||0        |1        |
# ------|------||---------|---------|
# region|0     || 0.9983  | 0.0017  |
# region|0     || 0.9947  | 0.0053  |
# region|0     || 0.9983  | 0.0017  |
# region|0     || 0.9995  | 0.0005  |
# region|0     || 0.9999  | 0.0001  |
# region|1     || 0.9983  | 0.0017  |
# region|1     || 0.9947  | 0.0053  |
# region|1     || 0.9983  | 0.0017  |
# region|1     || 0.9995  | 0.0005  |
# region|1     || 0.9999  | 0.0001  |

# %% [markdown]
# HighSpeed (X2)

# %%
dn.cpt("HighSpeed").fillWith([1-0.0068, 0.0068])
# Out:
# (pyAgrum.Potential<double>@0000026F0E36EDE0)
#   HighSpeed        |
# 0        |1        |
# ---------|---------|
#  0.9932  | 0.0068  |

# %% [markdown]
# EquipmentError (X3)

# %%
dn.cpt("EquipmentError").fillWith([1-0.008563, 0.008563])
# Out:
# (pyAgrum.Potential<double>@0000026F0E36EEE0)
#   EquipmentError   |
# 0        |1        |
# ---------|---------|
#  0.9914  | 0.0086  |

# %% [markdown]
# HumanError (X5)

# %%
dn.cpt("HumanError").fillWith([1-0.0074, 0.0074])
# Out:
# (pyAgrum.Potential<double>@0000026F0E36ED40)
#   HumanError       |
# 0        |1        |
# ---------|---------|
#  0.9926  | 0.0074  |

# %% [markdown]
# RadarFailure (X4)

# %%
dn.cpt("RadarFailure")[{"ShipFault":0}] = [1-0.0234, 0.0234]
dn.cpt("RadarFailure")[{"ShipFault":1}] = [1-0.0234, 0.0234]
dn.cpt("RadarFailure")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F220)
#       ||  RadarFailure     |
# ShipFa||0        |1        |
# ------||---------|---------|
# 0     || 0.9766  | 0.0234  |
# 1     || 0.9766  | 0.0234  |

# %% [markdown]
# ## CPT for conditionals

# %% [markdown]
# Navigation

# %%
vars = ["HumanError", "HighSpeed", "EquipmentError", "ShipFault"]
getIterations(vars, "Navigation", dn)
print("The below rounds to 4 decimal places but it is correct!")
dn.cpt("Navigation")
# Out:
# The below rounds to 4 decimal places but it is correct!
# (pyAgrum.Potential<double>@0000026F0E36F240)
#                            ||  Navigation       |
# ShipFa|HumanE|Equipm|HighSp||0        |1        |
# ------|------|------|------||---------|---------|
# 0     |0     |0     |0     || 1.0000  | 0.0000  |
# 1     |0     |0     |0     || 1.0000  | 0.0000  |
# 0     |1     |0     |0     || 1.0000  | 0.0000  |
# 1     |1     |0     |0     || 1.0000  | 0.0000  |
# 0     |0     |1     |0     || 1.0000  | 0.0000  |
# 1     |0     |1     |0     || 1.0000  | 0.0000  |
# [...4 more line(s) ...]
# 0     |1     |0     |1     || 1.0000  | 0.0000  |
# 1     |1     |0     |1     || 1.0000  | 0.0000  |
# 0     |0     |1     |1     || 1.0000  | 0.0000  |
# 1     |0     |1     |1     || 1.0000  | 0.0000  |
# 0     |1     |1     |1     || 1.0000  | 0.0000  |
# 1     |1     |1     |1     || 1.0000  | 0.0000  |

# %% [markdown]
# ShipFault

# %% [markdown]
# Used "Mechanical failure" from table 2 of Marine transportation risk assessment using Bayesian Network: Application to Arctic waters"

# %%
dn.cpt("ShipFault").fillWith([1-0.000287, 0.000287])
dn.cpt("ShipFault")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F020)
#   ShipFault        |
# 0        |1        |
# ---------|---------|
#  0.9997  | 0.0003  |

# %% [markdown]
# Environment

# %%
dn.cpt("Environment").fillWith([1-0.4247, 0.4247])
dn.cpt("Environment")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F3C0)
#   Environment      |
# 0        |1        |
# ---------|---------|
#  0.5753  | 0.4247  |

# %% [markdown]
# Collision <br> Used Table 8 and 9 in "Marine Transportation Risk Assessment using Bayesian Network: Application to Arctic Waters"

# %%
#dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 0}]=[1, 0] #No Collision
#dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 1}]=[1-0.00502, 0.00502] #Average of table 9
#dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 0}]=[1-0.00224, 0.00224] #Average of table 8
#dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 1}]=[1-0.00363, 0.00363] #Average of table 8 and 9
#dn.cpt("Collision")

dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 0, "Navigation":0}]=[1, 0] #No Collision
dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 1, "Navigation":0}]=[1-0.00502, 0.00502] #Average of table 9
dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 0, "Navigation":0}]=[1-0.00224, 0.00224] #Average of table 8
dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 1, "Navigation":0}]=[1-0.00363, 0.00363] #Average of table 8 and 9
dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 0, "Navigation":1}]=[1, 0] #No Collision
dn.cpt("Collision")[{"ShipFault": 0,  "Environment": 1, "Navigation":1}]=[1-0.00502, 0.00502] #Average of table 9
dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 0, "Navigation":1}]=[1-0.00224, 0.00224] #Average of table 8
dn.cpt("Collision")[{"ShipFault": 1,  "Environment": 1, "Navigation":1}]=[1-0.00363, 0.00363] #Average of table 8 and 9
dn.cpt("Collision")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36F120)
#                     ||  Collision        |
# Enviro|ShipFa|Naviga||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 1.0000  | 0.0000  |
# 1     |0     |0     || 0.9950  | 0.0050  |
# 0     |1     |0     || 0.9978  | 0.0022  |
# 1     |1     |0     || 0.9964  | 0.0036  |
# 0     |0     |1     || 1.0000  | 0.0000  |
# 1     |0     |1     || 0.9950  | 0.0050  |
# 0     |1     |1     || 0.9978  | 0.0022  |
# 1     |1     |1     || 0.9964  | 0.0036  |

# %%
print(dn)
gnb.showBN(dn,size="15")
# Out:
# Influence Diagram{
#   chance: 14,
#   utility: 1,
#   decision: 1,
#   arcs: 20,
#   domainSize: 81920
# }

# %% [markdown]
# <b> Note: <b> not sure how "ChangeCourse" works but I think that "ChangeCourse"=0 means that we do not continue and a value of 1 is that we do continue

# %%
dn.utility("U")[{"ChangeCourse":0, "Collision":0}] = 50 #Do not change course + no collision -> Nothing changes
dn.utility("U")[{"ChangeCourse":0, "Collision":1}] = -50 #Do not change course + collision -> Stay on a collision course
dn.utility("U")[{"ChangeCourse":1, "Collision":0}] = -25 #Change course + no collision -> Change course unnecessarily
dn.utility("U")[{"ChangeCourse":1, "Collision":1}] = 0 #Change course + collision -> Go off a collision course 
dn.utility("U")
# Out:
# (pyAgrum.Potential<double>@0000026F0E36EF20)
#              ||  U      |
# Collis|Change||0        |
# ------|------||---------|
# 0     |0     || 50.0000 |
# 1     |0     || -50.0000|
# 0     |1     || -25.0000|
# 1     |1     || 0.0000  |

# %% [markdown]
# # Inference

# %%
ie = gum.ShaferShenoyLIMIDInference(dn)
#ie.setEvidence({'s': [Pr(knowing|off), Pr(knowing|on)], 'c': [1, 0]}) , 
ie.setEvidence({"HighSpeed":[1,0.0068], "EquipmentError":[1,0.008563], "HumanError":[1,0.0076], "RadarFailure":[1, 0.0234]})
#I.e. at for RadarFailure: if there is a radar failure then we are only 2.34% certain that it has occured. If there is no failure then we know there isn't
ie.makeInference()
gnb.showInference(dn, evs={"HighSpeed":[1,0.0068], "EquipmentError":[1,0.008563], "HumanError":[1,0.0076], "RadarFailure":[1, 0.0234]}, size=15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[122], line 6
#       4 #I.e. at for RadarFailure: if there is a radar failure then we are only 2.34% certain that it has occured. If there is no failure then we know there isn't
#       5 ie.makeInference()
# ----> 6 gnb.showInference(dn, evs={"HighSpeed":[1,0.0068], "EquipmentError":[1,0.008563], "HumanError":[1,0.0076], "RadarFailure":[1, 0.0234]}, size=15)
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\notebook.py:1008, in showInference(model, **kwargs)
#    1005 else:
#    1006   size = gum.config["notebook", "default_graph_inference_size"]
# -> 1008 showGraph(prepareShowInference(model, **kwargs), size)
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\image.py:183, in prepareShowInference(model, engine, evs, targets, size, nodeColor, factorColor, arcWidth, arcColor, cmap, cmapArc, graph, view)
#     181   if engine is None:
#     182     engine = gum.ShaferShenoyLIMIDInference(model)
# --> 183   return LIMIDinference2dot(model, size=size, engine=engine, evs=evs, targets=targets)
#     184 if isinstance(model, gum.CredalNet):
#     185   if engine is None:
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\id2graph.py:198, in LIMIDinference2dot(diag, size, engine, evs, targets)
#     193 if len(targets) == 0 or name in targets or nid in targets:
#     194   # shape="rectangle"
#     195   filename = temp_dir + \
#     196              hashlib.md5(name.encode()).hexdigest() + "." + \
#     197              gum.config["notebook", "graph_format"]
# --> 198   saveFigProba(ie.posterior(name), filename, bgcolor=bgcolor, util=ie.posteriorUtility(nid), txtcolor=fgcolor)
#     199   dotstr += f' "{name}" [shape=rectangle,image="{filename}",label="", {colorattribute}];\n'
#     200 else:
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\proba_histogram.py:330, in saveFigProba(p, filename, util, bgcolor, txtcolor)
#     313 def saveFigProba(p, filename, util=None, bgcolor=None, txtcolor="Black"):
#     314   """
#     315   save a figure  which is the representation of a histogram for a mono-dim Potential
#     316
#    (...)
#     328       color for text
#     329   """
# --> 330   fig = proba2histo(p, util=util, txtcolor=txtcolor)
#     332   if bgcolor is None:
#     333     fc = gum.config["notebook", "figure_facecolor"]
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\proba_histogram.py:302, in proba2histo(p, scale, util, txtcolor)
#     282 """
#     283 compute the representation of a histogram for a mono-dim Potential
#     284
#    (...)
#     299   a matplotlib histogram for a Potential p.
#     300 """
#     301 if util is not None:
# --> 302   return _getProbaH(p, scale, util=util, txtcolor=txtcolor)
#     304 if p.variable(0).domainSize() > int(gum.config['notebook', 'histogram_line_threshold']):
#     305   return _getProbaLine(p, scale, txtcolor=txtcolor)
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyAgrum\lib\proba_histogram.py:248, in _getProbaH(p, scale, util, txtcolor)
#     245 fig.set_figheight(scale * var.domainSize() / 4.0)
#     246 fig.set_figwidth(scale * 2)
# --> 248 ax = fig.add_subplot(111)
#     249 ax.set_facecolor('white')
#     251 vals = p.tolist()
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:683, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     680 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     682 self._rasterization_zorder = None
# --> 683 self.clear()
#     685 # funcs used to format x and y - fall back on major formatters
#     686 self.fmt_xdata = None
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:1395, in _AxesBase.clear(self)
#    1393     self.cla()
#    1394 else:
# -> 1395     self.__clear()
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:1279, in _AxesBase.__clear(self)
#    1276 yaxis_visible = self.yaxis.get_visible()
#    1278 for axis in self._axis_map.values():
# -> 1279     axis.clear()  # Also resets the scale to linear.
#    1280 for spine in self.spines.values():
#    1281     spine.clear()
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:879, in Axis.clear(self)
#     875 self.labelpad = mpl.rcParams['axes.labelpad']
#     877 self._init()
# --> 879 self._set_scale('linear')
#     881 # Clear the callback registry for this axis, or it may "leak"
#     882 self.callbacks = cbook.CallbackRegistry(signals=["units"])
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:770, in Axis._set_scale(self, value, **kwargs)
#     768 else:
#     769     self._scale = value
# --> 770 self._scale.set_default_locators_and_formatters(self)
#     772 self.isDefault_majloc = True
#     773 self.isDefault_minloc = True
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\scale.py:105, in LinearScale.set_default_locators_and_formatters(self, axis)
#     103 def set_default_locators_and_formatters(self, axis):
#     104     # docstring inherited
# --> 105     axis.set_major_locator(AutoLocator())
#     106     axis.set_major_formatter(ScalarFormatter())
#     107     axis.set_minor_formatter(NullFormatter())
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\ticker.py:2900, in AutoLocator.__init__(self)
#    2898     nbins = 'auto'
#    2899     steps = [1, 2, 2.5, 5, 10]
# -> 2900 super().__init__(nbins=nbins, steps=steps)
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\ticker.py:2008, in MaxNLocator.__init__(self, nbins, **kwargs)
#    2006 if nbins is not None:
#    2007     kwargs['nbins'] = nbins
# -> 2008 self.set_params(**{**self.default_params, **kwargs})
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\ticker.py:2068, in MaxNLocator.set_params(self, **kwargs)
#    2066     else:
#    2067         self._steps = self._validate_steps(steps)
# -> 2068     self._extended_steps = self._staircase(self._steps)
#    2069 if 'integer' in kwargs:
#    2070     self._integer = kwargs.pop('integer')
#
# File c:\Users\shayl\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\ticker.py:2029, in MaxNLocator._staircase(steps)
#    2025 @staticmethod
#    2026 def _staircase(steps):
#    2027     # Make an extended staircase within which the needed step will be
#    2028     # found.  This is probably much larger than necessary.
# -> 2029     return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
#evidence = {"Fog":1, "PackIce":1,"HighSpeed":[1,0.0068], "EquipmentError":[1,0.008563], "HumanError":[1,0.0076], "RadarFailure":[1, 0.0234]}
evidence = {"Fog":1, "PackIce":1, "RidgeIceAndIceberg":1, "Waves":1, "HighWind":1, "HighSpeed":1, "EquipmentError":1, "HumanError":1,"RadarFailure":1}
ie.setEvidence(evidence)
ie.makeInference()
gnb.showInference(dn, evs=evidence, size=15)
